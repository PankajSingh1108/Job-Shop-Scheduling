# %%
""" Defined function for static initial data for Production Planning """

#importing libraries
import pandas as pd
import openpyxl as xl
import json

def data_excel_json(excel_sheet):
    """ convert excel into json """
    data_excel = xl.load_workbook(excel_sheet)
    data = {}
    sheet_name = data_excel.sheetnames
    for sheet in sheet_name:
        wb_sheet = data_excel[sheet]
        cell_values = wb_sheet.values
        df =  pd.DataFrame(cell_values, columns=next(cell_values))
        df.iloc[:, 0] = df.iloc[:, 0].apply(lambda x : x.strip())
        df.index = df.iloc[:, 0]
        df.drop(columns = df.columns[0], inplace=True)
        data[sheet] = df.T.to_dict()
    return data

def json_to_df(json_data):
    """ convert json into excel """
    dict_data = {}
    for key in json_data.keys():
        dict_data[key] = pd.DataFrame(json_data.get(key)).T
    return dict_data

# %%
! pip install chart-studio
# Out:
# Requirement already satisfied: chart-studio in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from chart-studio) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from chart-studio) (1.3.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from chart-studio) (2.23.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from chart-studio) (4.4.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->chart-studio) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->chart-studio) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->chart-studio) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->chart-studio) (2021.5.30)

# %%
''' Solving job shop scheduling problem by gentic algorithm '''

# importing required modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import chart_studio.plotly as py
import plotly.figure_factory as ff
import datetime
import time
import copy


def json_to_df(json_data):
    """ convert json into excel """
    dict_data = {}
    for key in json_data.keys():
        dict_data[key] = pd.DataFrame(json_data.get(key)).T

    return dict_data


def generate_initial_population(population_size, num_gene):

    """ generate initial population for Genetic Algorithm """

    best_list, best_obj = [], []
    population_list = []
    makespan_record = []
    for i in range(population_size):
        nxm_random_num = list(np.random.permutation(num_gene)) # generate a random permutation of 0 to num_job*num_mc-1
        population_list.append(nxm_random_num) # add to the population_list
        for j in range(num_gene):
            population_list[i][j] = population_list[i][j] % num_job # convert to job number format, every job appears m times

    return population_list



def job_schedule(data_dict, population_size = 30, crossover_rate = 0.8, mutation_rate = 0.2, mutation_selection_rate = 0.2, num_iteration = 2000):

    """ initialize genetic algorithm parameters and read data """
    data_json  = json_to_df(data_dict)
    machine_sequence_tmp = data_json['Machines Sequence']
    process_time_tmp = data_json['Processing Time']

    df_shape = process_time_tmp.shape
    num_machines = df_shape[1] # number of machines
    num_job = df_shape[0] # number of jobs
    num_gene = num_machines * num_job # number of genes in a chromosome
    num_mutation_jobs = round(num_gene * mutation_selection_rate)

    process_time = [list(map(int, process_time_tmp.iloc[i])) for i in range(num_job)]
    machine_sequence = [list(map(int, machine_sequence_tmp.iloc[i])) for i in range(num_job)]
    
    #start_time = time.time()

    Tbest = 999999999999999

    best_list, best_obj = [], []
    population_list = []
    makespan_record = []

    for i in range(population_size):
        nxm_random_num = list(np.random.permutation(num_gene)) # generate a random permutation of 0 to num_job*num_mc-1
        population_list.append(nxm_random_num) # add to the population_list
        for j in range(num_gene):
            population_list[i][j] = population_list[i][j] % num_job # convert to job number format, every job appears m times
    #population_list = generate_initial_population(population_size=population_size, num_gene=num_gene)


    for iteration in range(num_iteration):    
        Tbest_now = 99999999999

        """ Two Point Cross-Over """
        parent_list = copy.deepcopy(population_list)
        offspring_list = copy.deepcopy(population_list) # generate a random sequence to select the parent chromosome to crossover
        pop_random_size = list(np.random.permutation(population_size))

        for size in range(int(population_size/2)):
            crossover_prob = np.random.rand()
            if crossover_rate >= crossover_prob:
                parent_1 = population_list[pop_random_size[2*size]][:]
                parent_2 = population_list[pop_random_size[2*size+1]][:]

                child_1 = parent_1[:]
                child_2 = parent_2[:]
                cutpoint = list(np.random.choice(num_gene, 2, replace=False))
                cutpoint.sort()

                child_1[cutpoint[0]:cutpoint[1]] = parent_2[cutpoint[0]:cutpoint[1]]
                child_2[cutpoint[0]:cutpoint[1]] = parent_1[cutpoint[0]:cutpoint[1]]
                offspring_list[pop_random_size[2*size]] = child_1[:]
                offspring_list[pop_random_size[2*size+1]] = child_2[:]


        for pop in range(population_size):

            """ Repairment """
            job_count = {}
            larger, less = [], [] # 'larger' record jobs appear in the chromosome more than pop times, and 'less' records less than pop times.
            for job in range(num_job):
                if job in offspring_list[pop]:
                    count = offspring_list[pop].count(job)
                    pos = offspring_list[pop].index(job)
                    job_count[job] = [count, pos] # store the above two values to the job_count dictionary
                else:
                    count = 0
                    job_count[job] = [count, 0]

                if count > num_machines:
                    larger.append(job)
                elif count < num_machines:
                    less.append(job)
                    
            for large in range(len(larger)):
                change_job = larger[large]
                while job_count[change_job][0] > num_machines:
                    for les in range(len(less)):
                        if job_count[less[les]][0] < num_machines:                    
                            offspring_list[pop][job_count[change_job][1]] = less[les]
                            job_count[change_job][1] = offspring_list[pop].index(change_job)
                            job_count[change_job][0] = job_count[change_job][0]-1
                            job_count[less[les]][0] = job_count[less[les]][0]+1                    
                        if job_count[change_job][0] == num_machines:
                            break    


        for off_spring in range(len(offspring_list)):

            """ Mutations """
            mutation_prob = np.random.rand()
            if mutation_rate >= mutation_prob:
                m_change = list(np.random.choice(num_gene, num_mutation_jobs, replace=False)) # chooses the position to mutation
                t_value_last = offspring_list[off_spring][m_change[0]] # save the value which is on the first mutation position
                for i in range(num_mutation_jobs-1):
                    offspring_list[off_spring][m_change[i]] = offspring_list[off_spring][m_change[i+1]] # displacement
                # move the value of the first mutation position to the last mutation position
                offspring_list[off_spring][m_change[num_mutation_jobs-1]] = t_value_last 


        """ fitness value (calculate makespan) """
        total_chromosome = copy.deepcopy(parent_list) + copy.deepcopy(offspring_list) # parent and offspring chromosomes combination
        chrom_fitness, chrom_fit = [], []
        total_fitness = 0
        for pop_size in range(population_size*2):
            j_keys = [j for j in range(num_job)]
            key_count = {key:0 for key in j_keys}
            j_count = {key:0 for key in j_keys}
            m_keys = [j+1 for j in range(num_machines)]
            m_count = {key:0 for key in m_keys}
            
            for i in total_chromosome[pop_size]:
                gen_t = int(process_time[i][key_count[i]])
                gen_m = int(machine_sequence[i][key_count[i]])
                j_count[i] = j_count[i] + gen_t
                m_count[gen_m] = m_count[gen_m] + gen_t
                
                if m_count[gen_m] < j_count[i]:
                    m_count[gen_m] = j_count[i]
                elif m_count[gen_m] > j_count[i]:
                    j_count[i] = m_count[gen_m]
                
                key_count[i] = key_count[i] + 1
        
            makespan = max(j_count.values())
            chrom_fitness.append(1/makespan)
            chrom_fit.append(makespan)
            total_fitness = total_fitness + chrom_fitness[pop_size]


        """ Selection (roulette wheel approach) """
        pk, qk = [], []
        
        for size in range(population_size * 2):
            pk.append(chrom_fitness[size] / total_fitness)
        for size in range(population_size * 2):
            cumulative = 0

            for j in range(0, size+1):
                cumulative = cumulative + pk[j]
            qk.append(cumulative)
        
        selection_rand = [np.random.rand() for i in range(population_size)]
        
        for pop_size in range(population_size):
            if selection_rand[pop_size] <= qk[0]:
                population_list[pop_size] = copy.deepcopy(total_chromosome[0])
        else:
            for j in range(0, population_size * 2-1):
                if selection_rand[pop_size] > qk[j] and selection_rand[pop_size] <= qk[j+1]:
                    population_list[pop_size] = copy.deepcopy(total_chromosome[j+1])
                    break


        """ comparison """
        for pop_size in range(population_size * 2):
            if chrom_fit[pop_size] < Tbest_now:
                Tbest_now = chrom_fit[pop_size]
                sequence_now = copy.deepcopy(total_chromosome[pop_size])
        if Tbest_now <= Tbest:
            Tbest = Tbest_now
            sequence_best = copy.deepcopy(sequence_now)
            
        makespan_record.append(Tbest)

    """ Results - Makespan """
    print("optimal sequence", sequence_best)
    print("optimal value:%f"%Tbest)
    print("\n")
    #print('the elapsed time:%s'% (time.time() - start_time))

    #%matplotlib inline
    plt.plot([i for i in range(len(makespan_record))],makespan_record,'b')
    plt.ylabel('makespan', fontsize=15)
    plt.xlabel('generation', fontsize=15)
    plt.show()


    """ plot gantt chart """
    m_keys = [j+1 for j in range(num_machines)]
    j_keys = [j for j in range(num_job)]
    key_count = {key:0 for key in j_keys}
    j_count = {key:0 for key in j_keys}
    m_count = {key:0 for key in m_keys}
    j_record = {}
    for i in sequence_best:
        gen_t = int(process_time[i][key_count[i]])
        gen_m = int(machine_sequence[i][key_count[i]])
        j_count[i] = j_count[i] + gen_t
        m_count[gen_m] = m_count[gen_m] + gen_t

        if m_count[gen_m] < j_count[i]:
            m_count[gen_m] = j_count[i]
        elif m_count[gen_m] > j_count[i]:
            j_count[i] = m_count[gen_m]

        start_time = str(datetime.timedelta(seconds = j_count[i] - process_time[i][key_count[i]])) # convert seconds to hours, minutes and seconds
        end_time = str(datetime.timedelta(seconds = j_count[i]))

        j_record[(i, gen_m)] = [start_time, end_time]

        key_count[i] = key_count[i] + 1

    df = []
    for m in m_keys:
        for j in j_keys:
            df.append(dict(Task='Machine %s'%(m), Start='2020-02-01 %s'%(str(j_record[(j,m)][0])), \
                            Finish='2020-02-01 %s'%(str(j_record[(j,m)][1])),Resource='Job %s'%(j+1)))
    
    df_ = pd.DataFrame(df)
    df_.Start = pd.to_datetime(df_['Start'])
    df_.Finish = pd.to_datetime(df_['Finish'])
    start = df_.Start.min()
    end = df_.Finish.max()

    df_.Start = df_.Start.apply(lambda x: x.strftime('%Y-%m-%dT%H:%M:%S'))
    df_.Finish = df_.Finish.apply(lambda x: x.strftime('%Y-%m-%dT%H:%M:%S'))
    data = df_.to_dict('record')

    final_data ={
        'start':start.strftime('%Y-%m-%dT%H:%M:%S'),
        'end':end.strftime('%Y-%m-%dT%H:%M:%S'),
        'data':data}
        
    fig = ff.create_gantt(df, index_col='Resource', show_colorbar=True, group_tasks=True, showgrid_x=True, title='Job shop Schedule')
    fig.show()
    #iplot(fig, filename='GA_job_shop_scheduling')
    return final_data, df

# %%
""" Job_Shop_Schedule """

data = data_excel_json('JSP_dataset.xlsx')
schedule = job_schedule(data_dict=data)
# Out:
# optimal sequence [6, 5, 7, 0, 9, 4, 0, 5, 8, 9, 9, 3, 1, 1, 0, 5, 8, 0, 3, 6, 9, 8, 8, 2, 4, 5, 7, 8, 1, 4, 1, 7, 6, 3, 3, 0, 2, 7, 2, 3, 0, 9, 4, 7, 2, 1, 8, 8, 4, 4, 6, 5, 7, 3, 9, 9, 5, 9, 6, 7, 1, 4, 1, 1, 3, 5, 0, 9, 8, 4, 8, 6, 3, 5, 0, 6, 2, 7, 2, 4, 6, 0, 1, 2, 7, 8, 3, 6, 2, 5, 9, 2, 5, 6, 7, 1, 2, 0, 3, 4]
# optimal value:1185.000000
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:1490: FutureWarning:
#
# Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="02112122-8b7a-4dac-b607-c6c0eabf40b5" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("02112122-8b7a-4dac-b607-c6c0eabf40b5")) {
#                     Plotly.newPlot(
#                         '02112122-8b7a-4dac-b607-c6c0eabf40b5',
#                         [{"fill": "toself", "fillcolor": "rgb(127, 127, 127)", "hoverinfo": "name", "legendgroup": "rgb(127, 127, 127)", "mode": "none", "name": "Job 7", "showlegend": true, "type": "scatter", "x": ["2020-02-01 0:03:07", "2020-02-01 0:03:44", "2020-02-01 0:03:44", "2020-02-01 0:03:07", "2020-02-01 0:03:07", "2020-02-01 0:00:00", "2020-02-01 0:00:46", "2020-02-01 0:00:46", "2020-02-01 0:00:00", "2020-02-01 0:00:00", "2020-02-01 0:11:46", "2020-02-01 0:11:59", "2020-02-01 0:11:59", "2020-02-01 0:11:46", "2020-02-01 0:11:46", "2020-02-01 0:08:52", "2020-02-01 0:09:53", "2020-02-01 0:09:53", "2020-02-01 0:08:52", "2020-02-01 0:08:52", "2020-02-01 0:18:04", "2020-02-01 0:18:59", "2020-02-01 0:18:59", "2020-02-01 0:18:04", "2020-02-01 0:18:04", "2020-02-01 0:14:22", "2020-02-01 0:14:43", "2020-02-01 0:14:43", "2020-02-01 0:14:22", "2020-02-01 0:14:22", "2020-02-01 0:12:18", "2020-02-01 0:12:50", "2020-02-01 0:12:50", "2020-02-01 0:12:18", "2020-02-01 0:12:18", "2020-02-01 0:17:34", "2020-02-01 0:18:04", "2020-02-01 0:18:04", "2020-02-01 0:17:34", "2020-02-01 0:17:34", "2020-02-01 0:15:15", "2020-02-01 0:16:44", "2020-02-01 0:16:44", "2020-02-01 0:15:15", "2020-02-01 0:15:15", "2020-02-01 0:14:43", "2020-02-01 0:15:15", "2020-02-01 0:15:15", "2020-02-01 0:14:43"], "y": [8.8, 8.8, 9.2, 9.2, null, 7.8, 7.8, 8.2, 8.2, null, 6.8, 6.8, 7.2, 7.2, null, 5.8, 5.8, 6.2, 6.2, null, 4.8, 4.8, 5.2, 5.2, null, 3.8, 3.8, 4.2, 4.2, null, 2.8, 2.8, 3.2, 3.2, null, 1.8, 1.8, 2.2, 2.2, null, 0.8, 0.8, 1.2, 1.2, null, -0.2, -0.2, 0.2, 0.2]}, {"fill": "toself", "fillcolor": "rgb(140, 86, 75)", "hoverinfo": "name", "legendgroup": "rgb(140, 86, 75)", "mode": "none", "name": "Job 5", "showlegend": true, "type": "scatter", "x": ["2020-02-01 0:03:44", "2020-02-01 0:03:50", "2020-02-01 0:03:50", "2020-02-01 0:03:44", "2020-02-01 0:03:44", "2020-02-01 0:07:32", "2020-02-01 0:07:54", "2020-02-01 0:07:54", "2020-02-01 0:07:32", "2020-02-01 0:07:32", "2020-02-01 0:01:55", "2020-02-01 0:02:09", "2020-02-01 0:02:09", "2020-02-01 0:01:55", "2020-02-01 0:01:55", "2020-02-01 0:11:41", "2020-02-01 0:12:07", "2020-02-01 0:12:07", "2020-02-01 0:11:41", "2020-02-01 0:11:41", "2020-02-01 0:12:07", "2020-02-01 0:13:16", "2020-02-01 0:13:16", "2020-02-01 0:12:07", "2020-02-01 0:12:07", "2020-02-01 0:10:29", "2020-02-01 0:11:30", "2020-02-01 0:11:30", "2020-02-01 0:10:29", "2020-02-01 0:10:29", "2020-02-01 0:18:27", "2020-02-01 0:19:20", "2020-02-01 0:19:20", "2020-02-01 0:18:27", "2020-02-01 0:18:27", "2020-02-01 0:13:37", "2020-02-01 0:14:26", "2020-02-01 0:14:26", "2020-02-01 0:13:37", "2020-02-01 0:13:37", "2020-02-01 0:13:16", "2020-02-01 0:13:37", "2020-02-01 0:13:37", "2020-02-01 0:13:16", "2020-02-01 0:13:16", "2020-02-01 0:16:03", "2020-02-01 0:17:15", "2020-02-01 0:17:15", "2020-02-01 0:16:03"], "y": [8.8, 8.8, 9.2, 9.2, null, 7.8, 7.8, 8.2, 8.2, null, 6.8, 6.8, 7.2, 7.2, null, 5.8, 5.8, 6.2, 6.2, null, 4.8, 4.8, 5.2, 5.2, null, 3.8, 3.8, 4.2, 4.2, null, 2.8, 2.8, 3.2, 3.2, null, 1.8, 1.8, 2.2, 2.2, null, 0.8, 0.8, 1.2, 1.2, null, -0.2, -0.2, 0.2, 0.2]}, {"fill": "toself", "fillcolor": "rgb(148, 103, 189)", "hoverinfo": "name", "legendgroup": "rgb(148, 103, 189)", "mode": "none", "name": "Job 4", "showlegend": true, "type": "scatter", "x": ["2020-02-01 0:06:39", "2020-02-01 0:07:50", "2020-02-01 0:07:50", "2020-02-01 0:06:39", "2020-02-01 0:06:39", "2020-02-01 0:03:31", "2020-02-01 0:04:52", "2020-02-01 0:04:52", "2020-02-01 0:03:31", "2020-02-01 0:03:31", "2020-02-01 0:05:04", "2020-02-01 0:06:39", "2020-02-01 0:06:39", "2020-02-01 0:05:04", "2020-02-01 0:05:04", "2020-02-01 0:13:09", "2020-02-01 0:14:47", "2020-02-01 0:14:47", "2020-02-01 0:13:09", "2020-02-01 0:13:09", "2020-02-01 0:07:50", "2020-02-01 0:09:29", "2020-02-01 0:09:29", "2020-02-01 0:07:50", "2020-02-01 0:07:50", "2020-02-01 0:17:37", "2020-02-01 0:18:20", "2020-02-01 0:18:20", "2020-02-01 0:17:37", "2020-02-01 0:17:37", "2020-02-01 0:09:29", "2020-02-01 0:09:38", "2020-02-01 0:09:38 ...

# %%
# JSON to draw gantt chart 
schedule[0]
# Out:
# {'data': [{'Finish': '2020-02-01T00:03:54',
#    'Resource': 'Job 1',
#    'Start': '2020-02-01T00:03:25',
#    'Task': 'Machine 1'},
#   {'Finish': '2020-02-01T00:01:59',
#    'Resource': 'Job 2',
#    'Start': '2020-02-01T00:01:16',
#    'Task': 'Machine 1'},
#   {'Finish': '2020-02-01T00:05:31',
#    'Resource': 'Job 3',
#    'Start': '2020-02-01T00:04:06',
#    'Task': 'Machine 1'},
#   {'Finish': '2020-02-01T00:10:24',
#    'Resource': 'Job 4',
#    'Start': '2020-02-01T00:09:13',
#    'Task': 'Machine 1'},
#   {'Finish': '2020-02-01T00:05:37',
#    'Resource': 'Job 5',
#    'Start': '2020-02-01T00:05:31',
#    'Task': 'Machine 1'},
#   {'Finish': '2020-02-01T00:12:37',
#    'Resource': 'Job 6',
#    'Start': '2020-02-01T00:11:50',
#    'Task': 'Machine 1'},
#   {'Finish': '2020-02-01T00:09:01',
#    'Resource': 'Job 7',
#    'Start': '2020-02-01T00:08:24',
#    'Task': 'Machine 1'},
#   {'Finish': '2020-02-01T00:03:25',
#    'Resource': 'Job 8',
#    'Start': '2020-02-01T00:01:59',
#    'Task': 'Machine 1'},
#   {'Finish': '2020-02-01T00:01:16',
#    'Resource': 'Job 9',
#    'Start': '2020-02-01T00:00:00',
#    'Task': 'Machine 1'},
#   {'Finish': '2020-02-01T00:05:50',
#    'Resource': 'Job 10',
#    'Start': '2020-02-01T00:05:37',
#    'Task': 'Machine 1'},
#   {'Finish': '2020-02-01T00:10:32',
#    'Resource': 'Job 1',
#    'Start': '2020-02-01T00:09:14',
#    'Task': 'Machine 2'},
#   {'Finish': '2020-02-01T00:09:14',
#    'Resource': 'Job 2',
#    'Start': '2020-02-01T00:08:46',
#    'Task': 'Machine 2'},
#   {'Finish': '2020-02-01T00:04:06',
#    'Resource': 'Job 3',
#    'Start': '2020-02-01T00:02:35',
#    'Task': 'Machine 2'},
#   {'Finish': '2020-02-01T00:07:38',
#    'Resource': 'Job 4',
#    'Start': '2020-02-01T00:06:17',
#    'Task': 'Machine 2'},
#   {'Finish': '2020-02-01T00:08:46',
#    'Resource': 'Job 5',
#    'Start': '2020-02-01T00:08:24',
#    'Task': 'Machine 2'},
#   {'Finish': '2020-02-01T00:01:26',
#    'Resource': 'Job 6',
#    'Start': '2020-02-01T00:01:24',
#    'Task': 'Machine 2'},
#   {'Finish': '2020-02-01T00:08:24',
#    'Resource': 'Job 7',
#    'Start': '2020-02-01T00:07:38',
#    'Task': 'Machine 2'},
#   {'Finish': '2020-02-01T00:06:17',
#    'Resource': 'Job 8',
#    'Start': '2020-02-01T00:05:31',
#    'Task': 'Machine 2'},
#   {'Finish': '2020-02-01T00:02:35',
#    'Resource': 'Job 9',
#    'Start': '2020-02-01T00:01:26',
#    'Task': 'Machine 2'},
#   {'Finish': '2020-02-01T00:05:31',
#    'Resource': 'Job 10',
#    'Start': '2020-02-01T00:04:06',
#    'Task': 'Machine 2'},
#   {'Finish': '2020-02-01T00:10:41',
#    'Resource': 'Job 1',
#    'Start': '2020-02-01T00:10:32',
#    'Task': 'Machine 3'},
#   {'Finish': '2020-02-01T00:03:29',
#    'Resource': 'Job 2',
#    'Start': '2020-02-01T00:01:59',
#    'Task': 'Machine 3'},
#   {'Finish': '2020-02-01T00:07:24',
#    'Resource': 'Job 3',
#    'Start': '2020-02-01T00:06:10',
#    'Task': 'Machine 3'},
#   {'Finish': '2020-02-01T00:09:13',
#    'Resource': 'Job 4',
#    'Start': '2020-02-01T00:07:38',
#    'Task': 'Machine 3'},
#   {'Finish': '2020-02-01T00:03:43',
#    'Resource': 'Job 5',
#    'Start': '2020-02-01T00:03:29',
#    'Task': 'Machine 3'},
#   {'Finish': '2020-02-01T00:01:24',
#    'Resource': 'Job 6',
#    'Start': '2020-02-01T00:00:00',
#    'Task': 'Machine 3'},
#   {'Finish': '2020-02-01T00:12:31',
#    'Resource': 'Job 7',
#    'Start': '2020-02-01T00:12:18',
#    'Task': 'Machine 3'},
#   {'Finish': '2020-02-01T00:01:55',
#    'Resource': 'Job 8',
#    'Start': '2020-02-01T00:01:24',
#    'Task': 'Machine 3'},
#   {'Finish': '2020-02-01T00:12:06',
#    'Resource': 'Job 9',
#    'Start': '2020-02-01T00:10:41',
#    'Task': 'Machine 3'},
#   {'Finish': '2020-02-01T00:10:14',
#    'Resource': 'Job 10',
#    'Start': '2020-02-01T00:09:13',
#    'Task': 'Machine 3'},
#   {'Finish': '2020-02-01T00:11:17',
#    'Resource': 'Job 1',
#    'Start': '2020-02-01T00:10:41',
#    'Task': 'Machine 4'},
#   {'Finish': '2020-02-01T00:08:35',
#    'Resource': 'Job 2',
#    'Start': '2020-02-01T00:07:26',
#    'Task': 'Machine 4'},
#   {'Finish': '2020-02-01T00:06:10',
#    'Resource': 'Job 3',
#    'Start': '2020-02-01T00:05:31',
#    'Task': 'Machine 4'},
#   {'Finish': '2020-02-01T00:16:07',
#    'Resource': 'Job 4',
#    'Start': '2020-02-01T00:14:29',
#    'Task': 'Machine 4'},
#   {'Finish': '2020-02-01T00:10:31',
#    'Resource': 'Job 5',
#    'Start': '2020-02-01T00:10:05',
#    'Task': 'Machine 4'},
#   {'Finish': '2020-02-01T00:03:53',
#    'Resource': 'Job 6',
#    'Start': '2020-02-01T00:02:18',
#    'Task': 'Machine 4'},
#   {'Finish': '2020-02-01T00:12:18',
#    'Resource': 'Job 7',
#    'Start': '2020-02-01T00:11:17',
#    'Task': 'Machine 4'},
#   {'Finish': '2020-02-01T00:19:43',
#    'Resource': 'Job 8',
#    'Start': '2020-02-01T00:18:24',
#    'Task': 'Machine 4'},
#   {'Finish': '2020-02-01T00:07:26',
#    'Resource': 'Job 9',
#    'Start': '2020-02-01T00:06:10',
#    'Task': 'Machine 4'},
#   {'Finish': '2020-02-01T00:17:09',
#    'Resource': 'Job 10',
#    'Start': '2020-02-01T00:16:17',
#    'Task': 'Machine 4'},
#   {'Finish': '2020-02-01T00:12:52',
#    'Resource': 'Job 1',
#    'Start': '2020-02-01T00:12:03',
#    'Task': 'Machine 5'},
#   {'Finish': '2020-02-01T00:04:44',
#    'Resource': 'Job 2',
#    'Start': '2020-02-01T00:03:29',
#    'Task': 'Machine 5'},
#   {'Finish': '2020-02-01T00:14:34',
#    'Resource': 'Job 3',
#    'Start': '2020-02-01T00:14:01',
#    'Task': 'Machine 5'},
#   {'Finish': '2020-02-01T00:12:03',
#    'Resource': 'Job 4',
#    'Start': '2020-02-01T00:10:24',
#    'Task': 'Machine 5'},
#   {'Finish': '2020-02-01T00:14:01',
#    'Resource': 'Job 5',
#    'Start': '2020-02-01T00:12:52',
#    'Task': 'Machine 5'},
#   {'Finish': '2020-02-01T00:15:01',
#    'Resource': 'Job 6',
#    'Start': '2020-02-01T00:14:55',
#    'Task': 'Machine 5'},
#   {'Finish': '2020-02-01T00:19:34',
#    'Resource': 'Job 7',
#    'Start': '2020-02-01T00:18:39',
#    'Task': 'Machine 5'},
#   {'Finish': '2020-02-01T00:08:03',
#    'Resource': 'Job 8',
#    'Start': '2020-02-01T00:07:31',
#    'Task': 'Machine 5'},
#   {'Finish': '2020-02-01T00:20:00',
#    'Resource': 'Job 9',
#    'Start': '2020-02-01T00:19:34',
#    'Task': 'Machine 5'},
#   {'Finish': '2020-02-01T00:18:39',
#    'Resource': 'Job 10',
#    'Start': '2020-02-01T00:17:09',
#    'Task': 'Machine 5'},
#   {'Finish': '2020-02-01T00:13:35',
#    'Resource': 'Job 1',
#    'Start': '2020-02-01T00:13:24',
#    'Task': 'Machine 6'},
#   {'Finish': '2020-02-01T00:11:03',
#    'Resource': 'Job 2',
#    'Start': '2020-02-01T00:10:17',
#    'Task': 'Machine 6'},
#   {'Finish': '2020-02-01T00:09:04',
#    'Resource': 'Job 3',
#    'Start': '2020-02-01T00:08:54',
#    'Task': 'Machine 6'},
#   {'Finish': '2020-02-01T00:17:12',
#    'Resource': 'Job 4',
#    'Start': '2020-02-01T00:16:29',
#    'Task': 'Machine 6'},
#   {'Finish': '2020-02-01T00:10:05',
#    'Resource': 'Job 5',
#    'Start': '2020-02-01T00:09:04',
#    'Task': 'Machine 6'},
#   {'Finish': '2020-02-01T00:02:18',
#    'Resource': 'Job 6',
#    'Start': '2020-02-01T00:01:26',
#    'Task': 'Machine 6'},
#   {'Finish': '2020-02-01T00:13:24',
#    'Resource': 'Job 7',
#    'Start': '2020-02-01T00:13:03',
#    'Task': 'Machine 6'},
#   {'Finish': '2020-02-01T00:07:31',
#    'Resource': 'Job 8',
#    'Start': '2020-02-01T00:06:17',
#    'Task': 'Machine 6'},
#   {'Finish': '2020-02-01T00:08:22',
#    'Resource': 'Job 9',
#    'Start': '2020-02-01T00:07:31',
#    'Task': 'Machine 6'},
#   {'Finish': '2020-02-01T00:16:17',
#    'Resource': 'Job 10',
#    'Start': '2020-02-01T00:15:30',
#    'Task': 'Machine 6'},
#   {'Finish': '2020-02-01T00:15:57',
#    'Resource': 'Job 1',
#    'Start': '2020-02-01T00:14:55',
#    'Task': 'Machine 7'},
#   {'Finish': '2020-02-01T00:10:17',
#    'Resource': 'Job 2',
#    'Start': '2020-02-01T00:09:31',
#    'Task': 'Machine 7'},
#   {'Finish': '2020-02-01T00:11:46',
#    'Resource': 'Job 3',
#    'Start': '2020-02-01T00:10:17',
#    'Task': 'Machine 7'},
#   {'Finish': '2020-02-01T00:12:12',
#    'Resource': 'Job 4',
#    'Start': '2020-02-01T00:12:03',
#    'Task': 'Machine 7'},
#   {'Finish': '2020-02-01T00:19:28',
#    'Resource': 'Job 5',
#    'Start': '2020-02-01T00:18:35',
#    'Task': 'Machine 7'},
#   {'Finish': '2020-02-01T00:14:55',
#    'Resource': 'Job 6',
#    'Start': '2020-02-01T00:13:50',
#    'Task': 'Machine 7'},
#   {'Finish': '2020-02-01T00:13:03',
#    'Resource': 'Job 7',
#    'Start': '2020-02-01T00:12:31',
#    'Task': 'Machine 7'},
#   {'Finish': '2020-02-01T00:09:31',
#    'Resource': 'Job 8',
#    'Start': '2020-02-01T00:08:03',
#    'Task': 'Machine 7'},
#   {'Finish': '2020-02-01T00:13:50',
#    'Resource': 'Job 9',
#    'Start': '2020-02-01T00:13:10',
#    'Task': 'Machine 7'},
#   {'Finish': '2020-02-01T00:13:10',
#    'Resource': 'Job 10',
#    'Start': '2020-02-01T00:13:03',
#    'Task': 'Machine 7'},
#   {'Finish': '2020-02-01T00:19:20',
#    'Resource': 'Job 1',
#    'Start': '2020-02-01T00:18:24',
#    'Task': 'Machine 8'},
#   {'Finish': '2020-02-01T00:12:15',
#    'Resource': 'Job 2',
#    'Start': '2020-02-01T00:11:03',
#    'Task': 'Machine 8'},
#   {'Finish': '2020-02-01T00:09:16',
#    'Resource': 'Job 3',
#    'Start': '2020-02-01T00:09:04',
#    'Task': 'Machine 8'},
#   {'Finish': '2020-02-01T00:14:29',
#    'Resource': 'Job 4',
#    'Start': '2020-02-01T00:13:04',
#    'Task': 'Machine 8'},
#   {'Finish': '2020-02-01T00:17:23',
#    'Resource': 'Job 5',
#    'Start': '2020-02-01T00:16:34',
#    'Task': 'Machine 8'},
#   {'Finish': '2020-02-01T00:17:48',
#    'Resource': 'Job 6',
#    'Start': '2020-02-01T00:17:23',
#    'Task': 'Machine 8'},
#   {'Finish': '2020-02-01T00:16:34',
#    'Resource': 'Job 7',
#    'Start': '2020-02-01T00:16:04',
#    'Task': 'Machine 8'},
#   {'Finish': '2020-02-01T00:18:24',
#    'Resource': 'Job 8',
#    'Start': '2020-02-01T00:17:48',
#    'Task': 'Machine 8'},
#   {'Finish': '2020-02-01T00:15:58',
#    'Resource': 'Job 9',
#    'Start': '2020-02-01T00:14:29',
#    'Task': 'Machine 8'},
#   {'Finish': '2020-02-01T00:20:05',
#    'Resource': 'Job 10',
#    'Start': '2020-02-01T00:19:20',
#    'Task': 'Machine 8'},
#   {'Finish': '2020-02-01T00:20:04',
#    'Resource': 'Job 1',
#    'Start': '2020-02-01T00:19:20',
#    'Task': 'Machine 9'},
#   {'Finish': '2020-02-01T00:16:34',
#    'Resource': 'Job 2',
#    'Start': '2020-02-01T00:16:04',
#    'Task': 'Machine 9'},
#   {'Finish': '2020-02-01T00:08:54',
#    'Resource': 'Job 3',
#    'Start': '2020-02-01T00:07:24',
#    'Task': 'Machine 9'},
#   {'Finish': '2020-02-01T00:13:04',
#    'Resource': 'Job 4',
#    'Start': '2020-02-01T00:12:12',
#    'Task': 'Machine 9'},
#   {'Finish': '2020-02-01T00:14:35',
#    'Resource': 'Job 5',
#    'Start': '2020-02-01T00:14:14',
#    'Task': 'Machine 9'},
#   {'Finish': '2020-02-01T00:10:38',
#    'Resource': 'Job 6',
#    'Start': '2020-02-01T00:09:50',
#    'Task': 'Machine 9'},
#   {'Finish': '2020-02-01T00:16:04',
#    'Resource': 'Job 7',
#    'Start': '2020-02-01T00:14:35',
#    'Task': 'Machine 9'},
#   {'Finish': '2020-02-01T00:09:50',
#    'Resource': 'Job 8',
#    'Start': '2020-02-01T00:09:31',
#    'Task': 'Machine 9'},
#   {'Finish': '2020-02-01T00:21:18',
#    'Resource': 'Job 9',
#    'Start': '2020-02-01T00:20:04',
#    'Task': 'Machine 9'},
#   {'Finish': '2020-02-01T00:14:14',
#    'Resource': 'Job 10',
#    'Start': '2020-02-01T00:13:10',
#    'Task': 'Machine 9'},
#   {'Finish': '2020-02-01T00:20:25',
#    'Resource': 'Job 1',
#    'Start': '2020-02-01T00:20:04',
#    'Task': 'Machine 10'},
#   {'Finish': '2020-02-01T00:04:55',
#    'Resource': 'Job 2',
#    'Start': '2020-02-01T00:04:44',
#    'Task': 'Machine 10'},
#   {'Finish': '2020-02-01T00:13:02',
#    'Resource': 'Job 3',
#    'Start': '2020-02-01T00:12:17',
#    'Task': 'Machine 10'},
#   {'Finish': '2020-02-01T00:16:29',
#    'Resource': 'Job 4',
#    'Start': '2020-02-01T00:16:07',
#    'Task': 'Machine 10'},
#   {'Finish': '2020-02-01T00:18:35',
#    'Resource': 'Job 5',
#    'Start': '2020-02-01T00:17:23',
#    'Task': 'Machine 10'},
#   {'Finish': '2020-02-01T00:11:50',
#    'Resource': 'Job 6',
#    'Start': '2020-02-01T00:10:38',
#    'Task': 'Machine 10'},
#   {'Finish': '2020-02-01T00:13:56',
#    'Resource': 'Job 7',
#    'Start': '2020-02-01T00:13:24',
#    'Task': 'Machine 10'},
#   {'Finish': '2020-02-01T00:10:38',
#    'Resource': 'Job 8',
#    'Start': '2020-02-01T00:09:50',
#    'Task': 'Machine 10'},
#   {'Finish': '2020-02-01T00:12:17',
#    'Resource': 'Job 9',
#    'Start': '2020-02-01T00:12:06',
#    'Task': 'Machine 10'},
#   {'Finish': '2020-02-01T00:15:30',
#    'Resource': 'Job 10',
#    'Start': '2020-02-01T00:14:14',
#    'Task': 'Machine 10'}],
#  'end': '2020-02-01T00:21:18',
#  'start': '2020-02-01T00:00:00'}

# %%
import chart_studio.plotly as py
import plotly.figure_factory as ff

df = schedule[1]
fig = ff.create_gantt(df, index_col='Resource', show_colorbar=True, group_tasks=True, showgrid_x=True, title='Job shop Schedule')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6cd06980-696e-43ae-a251-c235677b0178" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6cd06980-696e-43ae-a251-c235677b0178")) {
#                     Plotly.newPlot(
#                         '6cd06980-696e-43ae-a251-c235677b0178',
#                         [{"fill": "toself", "fillcolor": "rgb(127, 127, 127)", "hoverinfo": "name", "legendgroup": "rgb(127, 127, 127)", "mode": "none", "name": "Job 7", "showlegend": true, "type": "scatter", "x": ["2020-02-01 0:08:24", "2020-02-01 0:09:01", "2020-02-01 0:09:01", "2020-02-01 0:08:24", "2020-02-01 0:08:24", "2020-02-01 0:07:38", "2020-02-01 0:08:24", "2020-02-01 0:08:24", "2020-02-01 0:07:38", "2020-02-01 0:07:38", "2020-02-01 0:12:18", "2020-02-01 0:12:31", "2020-02-01 0:12:31", "2020-02-01 0:12:18", "2020-02-01 0:12:18", "2020-02-01 0:11:17", "2020-02-01 0:12:18", "2020-02-01 0:12:18", "2020-02-01 0:11:17", "2020-02-01 0:11:17", "2020-02-01 0:18:39", "2020-02-01 0:19:34", "2020-02-01 0:19:34", "2020-02-01 0:18:39", "2020-02-01 0:18:39", "2020-02-01 0:13:03", "2020-02-01 0:13:24", "2020-02-01 0:13:24", "2020-02-01 0:13:03", "2020-02-01 0:13:03", "2020-02-01 0:12:31", "2020-02-01 0:13:03", "2020-02-01 0:13:03", "2020-02-01 0:12:31", "2020-02-01 0:12:31", "2020-02-01 0:16:04", "2020-02-01 0:16:34", "2020-02-01 0:16:34", "2020-02-01 0:16:04", "2020-02-01 0:16:04", "2020-02-01 0:14:35", "2020-02-01 0:16:04", "2020-02-01 0:16:04", "2020-02-01 0:14:35", "2020-02-01 0:14:35", "2020-02-01 0:13:24", "2020-02-01 0:13:56", "2020-02-01 0:13:56", "2020-02-01 0:13:24"], "y": [8.8, 8.8, 9.2, 9.2, null, 7.8, 7.8, 8.2, 8.2, null, 6.8, 6.8, 7.2, 7.2, null, 5.8, 5.8, 6.2, 6.2, null, 4.8, 4.8, 5.2, 5.2, null, 3.8, 3.8, 4.2, 4.2, null, 2.8, 2.8, 3.2, 3.2, null, 1.8, 1.8, 2.2, 2.2, null, 0.8, 0.8, 1.2, 1.2, null, -0.2, -0.2, 0.2, 0.2]}, {"fill": "toself", "fillcolor": "rgb(140, 86, 75)", "hoverinfo": "name", "legendgroup": "rgb(140, 86, 75)", "mode": "none", "name": "Job 5", "showlegend": true, "type": "scatter", "x": ["2020-02-01 0:05:31", "2020-02-01 0:05:37", "2020-02-01 0:05:37", "2020-02-01 0:05:31", "2020-02-01 0:05:31", "2020-02-01 0:08:24", "2020-02-01 0:08:46", "2020-02-01 0:08:46", "2020-02-01 0:08:24", "2020-02-01 0:08:24", "2020-02-01 0:03:29", "2020-02-01 0:03:43", "2020-02-01 0:03:43", "2020-02-01 0:03:29", "2020-02-01 0:03:29", "2020-02-01 0:10:05", "2020-02-01 0:10:31", "2020-02-01 0:10:31", "2020-02-01 0:10:05", "2020-02-01 0:10:05", "2020-02-01 0:12:52", "2020-02-01 0:14:01", "2020-02-01 0:14:01", "2020-02-01 0:12:52", "2020-02-01 0:12:52", "2020-02-01 0:09:04", "2020-02-01 0:10:05", "2020-02-01 0:10:05", "2020-02-01 0:09:04", "2020-02-01 0:09:04", "2020-02-01 0:18:35", "2020-02-01 0:19:28", "2020-02-01 0:19:28", "2020-02-01 0:18:35", "2020-02-01 0:18:35", "2020-02-01 0:16:34", "2020-02-01 0:17:23", "2020-02-01 0:17:23", "2020-02-01 0:16:34", "2020-02-01 0:16:34", "2020-02-01 0:14:14", "2020-02-01 0:14:35", "2020-02-01 0:14:35", "2020-02-01 0:14:14", "2020-02-01 0:14:14", "2020-02-01 0:17:23", "2020-02-01 0:18:35", "2020-02-01 0:18:35", "2020-02-01 0:17:23"], "y": [8.8, 8.8, 9.2, 9.2, null, 7.8, 7.8, 8.2, 8.2, null, 6.8, 6.8, 7.2, 7.2, null, 5.8, 5.8, 6.2, 6.2, null, 4.8, 4.8, 5.2, 5.2, null, 3.8, 3.8, 4.2, 4.2, null, 2.8, 2.8, 3.2, 3.2, null, 1.8, 1.8, 2.2, 2.2, null, 0.8, 0.8, 1.2, 1.2, null, -0.2, -0.2, 0.2, 0.2]}, {"fill": "toself", "fillcolor": "rgb(148, 103, 189)", "hoverinfo": "name", "legendgroup": "rgb(148, 103, 189)", "mode": "none", "name": "Job 4", "showlegend": true, "type": "scatter", "x": ["2020-02-01 0:09:13", "2020-02-01 0:10:24", "2020-02-01 0:10:24", "2020-02-01 0:09:13", "2020-02-01 0:09:13", "2020-02-01 0:06:17", "2020-02-01 0:07:38", "2020-02-01 0:07:38", "2020-02-01 0:06:17", "2020-02-01 0:06:17", "2020-02-01 0:07:38", "2020-02-01 0:09:13", "2020-02-01 0:09:13", "2020-02-01 0:07:38", "2020-02-01 0:07:38", "2020-02-01 0:14:29", "2020-02-01 0:16:07", "2020-02-01 0:16:07", "2020-02-01 0:14:29", "2020-02-01 0:14:29", "2020-02-01 0:10:24", "2020-02-01 0:12:03", "2020-02-01 0:12:03", "2020-02-01 0:10:24", "2020-02-01 0:10:24", "2020-02-01 0:16:29", "2020-02-01 0:17:12", "2020-02-01 0:17:12", "2020-02-01 0:16:29", "2020-02-01 0:16:29", "2020-02-01 0:12:03", "2020-02-01 0:12:12", "2020-02-01 0:12:12 ...
